# %%
# cd /mnt/59E0-214E/data/Jack/SavageLab/scripts/tecantaloupe
# %cd /Volumes/Shared/data/Jack/SavageLab/scripts/tecantaloupe
# Out:
# /Volumes/Shared/data/Jack/SavageLab/scripts/tecantaloupe

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn
import itertools

from growth.plate_spec import PlateSpec
from growth.plate_time_course_parser import SavageLabM1000Excel
from matplotlib import pyplot as plt

# %%
# PlateSpec defined in CSV for easy editing
ps = PlateSpec.FromFile('growth/plate_specs/2018_08_30_pFA_EZ_inhibition.csv')
name_mapping = ps.well_to_name_mapping()

# PlateSpec contains a DataFrame with the mapping. 
ps.df
# Out:
# value_type           name                                                   \
# column                  1              2              3                  4
# A            BW+pFA-sfGFP   BW+pFA-sfGFP   BW+pFA-sfGFP   BW+pFA-sfGFP+aTc
# B           CAF+pFA-sfGFP  CAF+pFA-sfGFP  CAF+pFA-sfGFP  CAF+pFA-sfGFP+aTc
# C             CAF+pFA-CAN    CAF+pFA-CAN    CAF+pFA-CAN    CAF+pFA-CAN+aTc
# D            CAF+pFA-HCA2   CAF+pFA-HCA2   CAF+pFA-HCA2   CAF+pFA-HCA2+aTc
# E            CAF+pFA-sbtA   CAF+pFA-sbtA   CAF+pFA-sbtA   CAF+pFA-sbtA+aTc
# F            CAF+pFA-DAB1   CAF+pFA-DAB1   CAF+pFA-DAB1   CAF+pFA-DAB1+aTc
# G            CAF+pFA-DAB2   CAF+pFA-DAB2   CAF+pFA-DAB2   CAF+pFA-DAB2+aTc
# H           CAF+pFA-CCM11  CAF+pFA-CCM11  CAF+pFA-CCM11  CAF+pFA-CCM11+aTc
#
# value_type                                                                   \
# column                      5                  6                          7
# A            BW+pFA-sfGFP+aTc   BW+pFA-sfGFP+aTc   BW+pFA-sfGFP+aTc+250uMEZ
# B           CAF+pFA-sfGFP+aTc  CAF+pFA-sfGFP+aTc  CAF+pFA-sfGFP+aTc+250uMEZ
# C             CAF+pFA-CAN+aTc    CAF+pFA-CAN+aTc    CAF+pFA-CAN+aTc+250uMEZ
# D            CAF+pFA-HCA2+aTc   CAF+pFA-HCA2+aTc   CAF+pFA-HCA2+aTc+250uMEZ
# E            CAF+pFA-sbtA+aTc   CAF+pFA-sbtA+aTc   CAF+pFA-sbtA+aTc+250uMEZ
# F            CAF+pFA-DAB1+aTc   CAF+pFA-DAB1+aTc   CAF+pFA-DAB1+aTc+250uMEZ
# G            CAF+pFA-DAB2+aTc   CAF+pFA-DAB2+aTc   CAF+pFA-DAB2+aTc+250uMEZ
# H           CAF+pFA-CCM11+aTc  CAF+pFA-CCM11+aTc  CAF+pFA-CCM11+aTc+250uMEZ
#
# value_type                                                        \
# column                              8                          9
# A            BW+pFA-sfGFP+aTc+250uMEZ   BW+pFA-sfGFP+aTc+250uMEZ
# B           CAF+pFA-sfGFP+aTc+250uMEZ  CAF+pFA-sfGFP+aTc+250uMEZ
# C             CAF+pFA-CAN+aTc+250uMEZ    CAF+pFA-CAN+aTc+250uMEZ
# D            CAF+pFA-HCA2+aTc+250uMEZ   CAF+pFA-HCA2+aTc+250uMEZ
# E            CAF+pFA-sbtA+aTc+250uMEZ   CAF+pFA-sbtA+aTc+250uMEZ
# F            CAF+pFA-DAB1+aTc+250uMEZ   CAF+pFA-DAB1+aTc+250uMEZ
# G            CAF+pFA-DAB2+aTc+250uMEZ   CAF+pFA-DAB2+aTc+250uMEZ
# H           CAF+pFA-CCM11+aTc+250uMEZ  CAF+pFA-CCM11+aTc+250uMEZ
#
# value_type                                                        \
# column                             10                         11
# A            BW+pFA-sfGFP+aTc+500uMEZ   BW+pFA-sfGFP+aTc+500uMEZ
# B           CAF+pFA-sfGFP+aTc+500uMEZ  CAF+pFA-sfGFP+aTc+500uMEZ
# C             CAF+pFA-CAN+aTc+500uMEZ    CAF+pFA-CAN+aTc+500uMEZ
# D            CAF+pFA-HCA2+aTc+500uMEZ   CAF+pFA-HCA2+aTc+500uMEZ
# E            CAF+pFA-sbtA+aTc+500uMEZ   CAF+pFA-sbtA+aTc+500uMEZ
# F            CAF+pFA-DAB1+aTc+500uMEZ   CAF+pFA-DAB1+aTc+500uMEZ
# G            CAF+pFA-DAB2+aTc+500uMEZ   CAF+pFA-DAB2+aTc+500uMEZ
# H           CAF+pFA-CCM11+aTc+500uMEZ  CAF+pFA-CCM11+aTc+500uMEZ
#
# value_type
# column                             12
# A            BW+pFA-sfGFP+aTc+500uMEZ
# B           CAF+pFA-sfGFP+aTc+500uMEZ
# C             CAF+pFA-CAN+aTc+500uMEZ
# D            CAF+pFA-HCA2+aTc+500uMEZ
# E            CAF+pFA-sbtA+aTc+500uMEZ
# F            CAF+pFA-DAB1+aTc+500uMEZ
# G            CAF+pFA-DAB2+aTc+500uMEZ
# H           CAF+pFA-CCM11+aTc+500uMEZ

# %%
parser = SavageLabM1000Excel()
timecourse = parser.ParseFromFilename('growth/data/2018_08_29_pFA_EZ_High.xlsx')

blanked = timecourse.blank()
# You can blank each well against it's own early timepoints
# by not setting blank_wells

# Smooth with default params.
smoothed = blanked.smooth()
# Out:
# /usr/local/lib/python3.6/site-packages/pandas/io/excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)
# /Volumes/Shared/data/Jack/SavageLab/scripts/tecantaloupe/growth/plate_time_course_parser.py:80: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   return clipped_df.convert_objects(convert_numeric=True)

# %%
# Smoothed & blanked data.
fig = plt.figure(figsize=(10,10))
OD_data = smoothed.data_for_label('abs600')
OD_data.plot(x='time_s', legend=False)
plt.show()

# %%
means = smoothed.mean_by_name(ps)
sems = smoothed.sem_by_name(ps)

mean_OD = means.data_for_label('abs600')
sems_OD = sems.data_for_label('abs600')

# %%
# groupings of samples for plotting
pos = [c for c in mean_OD.columns
       if c.startswith('BW') or c.startswith('CAF+pFA-CAN')or c.startswith('CAF+pFA-HCA2')or c.startswith('CAF+pFA-SbtA')]
neg = [c for c in mean_OD.columns
       if c.startswith('CAF+pFA-sf')]
exp = [c for c in mean_OD.columns
       if c.startswith('CAF+pFA-D') or c.startswith('CAF+pFA-CC')]

# %%
# to_plot = [
#     ('bw+pFE-sfGFP+atc', 'WT vector (+)'),
#     ('CAF+pFE-sfGFP+atc', 'vector (-)'),
#     ('CAF+pFE-HCA2+atc', 'HCAII (+)'),
#     ('CAF+pFE-DAB2_wt+atc', 'DAB2'),
#     ('CAF+pFE-DAB2+dAsp1+atc', 'DAB2 D538A'),
#     ('CAF+pFE-DAB2+dCys1+atc', 'DAB2 C539A'),
#     ('CAF+pFE-DAB2+dCys2+atc', 'DAB2 C542A'),
#     ('CAF+pFE-DAB2+dCys_1&2+atc', 'DAB2 2C2A'),
#     ('CAF+pFE-DAB2+dHis1+atc', 'DAB2 H524A'), 
#     ('CAF+pFE-DAB2+dHis2+atc', 'DAB2 H533A')]

# %%
seaborn.set_style('white')
pos_to_plot = pos
exp_to_plot = exp
neg_to_plot = neg

plt.figure(figsize=(20,10))
time_h = mean_OD.time_s / (60.0*60.0)

colors = seaborn.color_palette()
for i, c in enumerate(pos_to_plot):
    label = c
    color = colors[i % len(colors)]
    plt.fill_between(time_h, mean_OD[c] - sems_OD[c], mean_OD[c] + sems_OD[c],
                     color=color, alpha=0.5)
    plt.plot(time_h, mean_OD[c], label=label, color=color)

for i, c in enumerate(neg_to_plot):
    label = c
    color = colors[i % len(colors)]
    plt.fill_between(time_h, mean_OD[c] - sems_OD[c], mean_OD[c] + sems_OD[c],
                     color=color, alpha=0.5)
    plt.plot(time_h, mean_OD[c], label=label, color=color,ls='--')
    
# for i, c in enumerate(exp_to_plot):
#     label = c
#     color = colors[i % len(colors)]
#     plt.fill_between(time_h, mean_OD[c] - sems_OD[c], mean_OD[c] + sems_OD[c],
#                      color=color, alpha=0.5)
#     plt.plot(time_h, mean_OD[c], label=label, color=color,ls='-.')
plt.legend(loc=2, fontsize=18)
plt.xlim(0, np.max(time_h)+.1)
plt.ylim(-0.1, 1.3)
plt.xticks(np.arange(0, np.max(time_h)+.1, 5), fontsize=14)
plt.yticks(fontsize=14)
plt.title('Growth  metal binders', fontsize=20)
plt.xlabel('Time (Hours)', fontsize=20)
plt.ylabel('OD600', fontsize=20)

plt.show()

# %%
seaborn.set_style('white')
pos_to_plot = pos
exp_to_plot = exp
neg_to_plot = neg

plt.figure(figsize=(20,10))
time_h = mean_OD.time_s / (60.0*60.0)

colors = seaborn.color_palette()
# for i, c in enumerate(pos_to_plot):
#     label = c
#     color = colors[i % len(colors)]
#     plt.fill_between(time_h, mean_OD[c] - sems_OD[c], mean_OD[c] + sems_OD[c],
#                      color=color, alpha=0.5)
#     plt.plot(time_h, mean_OD[c], label=label, color=color)

# for i, c in enumerate(neg_to_plot):
#     label = c
#     color = colors[i % len(colors)]
#     plt.fill_between(time_h, mean_OD[c] - sems_OD[c], mean_OD[c] + sems_OD[c],
#                      color=color, alpha=0.5)
#     plt.plot(time_h, mean_OD[c], label=label, color=color,ls='--')
    
for i, c in enumerate(exp_to_plot):
    label = c
    color = colors[i % len(colors)]
    plt.fill_between(time_h, mean_OD[c] - sems_OD[c], mean_OD[c] + sems_OD[c],
                     color=color, alpha=0.5)
    plt.plot(time_h, mean_OD[c], label=label, color=color,ls='-.')
plt.legend(loc=2, fontsize=18)
plt.xlim(0, np.max(time_h)+.1)
plt.ylim(-0.1, 1.3)
plt.xticks(np.arange(0, np.max(time_h)+.1, 5), fontsize=14)
plt.yticks(fontsize=14)
plt.title('Growth  metal binders', fontsize=20)
plt.xlabel('Time (Hours)', fontsize=20)
plt.ylabel('OD600', fontsize=20)

plt.show()

# %%
exp_jack = [c for c in mean_OD.columns
       if c.startswith('CAF+pFA-HCA2+') or c.startswith('CAF+pFA-DAB2+') or c.startswith('CAF+pFA-CAN+') or c.startswith('CAF+pFA-SbtA+')]

seaborn.set_style('white')
pos_to_plot = pos
exp_to_plot = exp_jack
neg_to_plot = neg

plt.figure(figsize=(20,10))
time_h = mean_OD.time_s / (60.0*60.0)

colors = seaborn.color_palette()
# for i, c in enumerate(pos_to_plot):
#     label = c
#     color = colors[i % len(colors)]
#     plt.fill_between(time_h, mean_OD[c] - sems_OD[c], mean_OD[c] + sems_OD[c],
#                      color=color, alpha=0.5)
#     plt.plot(time_h, mean_OD[c], label=label, color=color)

# for i, c in enumerate(neg_to_plot):
#     label = c
#     color = colors[i % len(colors)]
#     plt.fill_between(time_h, mean_OD[c] - sems_OD[c], mean_OD[c] + sems_OD[c],
#                      color=color, alpha=0.5)
#     plt.plot(time_h, mean_OD[c], label=label, color=color,ls='--')
    
for i, c in enumerate(exp_to_plot):
    label = c
    color = colors[i % len(colors)]
    plt.fill_between(time_h, mean_OD[c] - sems_OD[c], mean_OD[c] + sems_OD[c],
                     color=color, alpha=0.5)
    plt.plot(time_h, mean_OD[c], label=label, color=color,ls='-.')
plt.legend(loc=2, fontsize=14)
plt.xlim(0, np.max(time_h)+.1)
plt.ylim(-0.1, 1.3)
plt.xticks(np.arange(0, np.max(time_h)+.1, 5), fontsize=14)
plt.yticks(fontsize=14)
plt.title('Growth  with inhibitor', fontsize=20)
plt.xlabel('Time (Hours)', fontsize=20)
plt.ylabel('OD600', fontsize=20)

plt.show()

# %%
exp_jack = [c for c in mean_OD.columns
       if c.startswith('CAF+pFA-DAB2') or c.startswith('BW')]

seaborn.set_style('white')
pos_to_plot = pos
exp_to_plot = exp_jack
neg_to_plot = neg

plt.figure(figsize=(20,10))
time_h = mean_OD.time_s / (60.0*60.0)

colors = seaborn.color_palette()
# for i, c in enumerate(pos_to_plot):
#     label = c
#     color = colors[i % len(colors)]
#     plt.fill_between(time_h, mean_OD[c] - sems_OD[c], mean_OD[c] + sems_OD[c],
#                      color=color, alpha=0.5)
#     plt.plot(time_h, mean_OD[c], label=label, color=color)

# for i, c in enumerate(neg_to_plot):
#     label = c
#     color = colors[i % len(colors)]
#     plt.fill_between(time_h, mean_OD[c] - sems_OD[c], mean_OD[c] + sems_OD[c],
#                      color=color, alpha=0.5)
#     plt.plot(time_h, mean_OD[c], label=label, color=color,ls='--')
    
for i, c in enumerate(exp_to_plot):
    label = c
    color = colors[i % len(colors)]
    plt.fill_between(time_h, mean_OD[c] - sems_OD[c], mean_OD[c] + sems_OD[c],
                     color=color, alpha=0.5)
    plt.plot(time_h, mean_OD[c], label=label, color=color,ls='-.')
plt.legend(loc=2, fontsize=18)
plt.xlim(0, np.max(time_h)+.1)
plt.ylim(-0.1, 1.3)
plt.xticks(np.arange(0, np.max(time_h)+.1, 5), fontsize=14)
plt.yticks(fontsize=14)
plt.title('Growth  with inhibitor', fontsize=20)
plt.xlabel('Time (Hours)', fontsize=20)
plt.ylabel('OD600', fontsize=20)

plt.show()

# %%
lag_times = means.LagTime(density_label='abs600')

labels = sorted(pos) + sorted(exp) + sorted(neg)
lags = [lag_times[l] for l in labels]

# Note - samples that don't cross the threshold get a 0 lag value.
figure = plt.figure(figsize=(10,10))
xs = np.arange(len(lags))
plt.bar(xs, lags)
plt.ylabel('Lag Time (hrs)')
plt.xticks(xs + 0.4, labels, rotation=90)
plt.show()

# %%
growth_rates = means.MaxGrowthRates(density_label='abs600')

labels = sorted(pos) + sorted(exp) + sorted(neg)
grs = [growth_rates[l] for l in labels]

figure = plt.figure(figsize=(10,10))
xs = np.arange(len(lags))
plt.bar(xs, grs)
plt.ylabel('Max Growth Rate (/hr)')
plt.xticks(xs + 0.4, labels, rotation=90)
plt.show()
# Out:
# /Volumes/Shared/data/Jack/SavageLab/scripts/tecantaloupe/growth/plate_time_course.py:384: RuntimeWarning: invalid value encountered in log
#   log_data = np.log(well_data)
# /Volumes/Shared/data/Jack/SavageLab/scripts/tecantaloupe/growth/plate_time_course.py:394: RuntimeWarning: All-NaN slice encountered
#   if np.nanmin(local_data) < log_lb:

# %%
yields = means.GrowthYield(density_label='abs600')

labels = sorted(pos) + sorted(exp) + sorted(neg)
ylds = [yields[l] for l in labels]

figure = plt.figure(figsize=(10,10))
xs = np.arange(len(ylds))
plt.bar(xs, ylds)
plt.ylabel('Growth Yield (OD600 Units)')
plt.xticks(xs + 0.4, labels, rotation=90)
plt.show()

# %%
seaborn.set_style('white')
pos_to_plot = pos
exp_to_plot = exp_jw
neg_to_plot = neg

plt.figure(figsize=(20,10))
time_h = mean_OD.time_s / (60.0*60.0)

colors = seaborn.color_palette()
# for i, c in enumerate(pos_to_plot):
#     label = c
#     color = colors[i % len(colors)]
#     plt.fill_between(time_h, mean_OD[c] - sems_OD[c], mean_OD[c] + sems_OD[c],
#                      color=color, alpha=0.5)
#     plt.plot(time_h, mean_OD[c], label=label, color=color)

# for i, c in enumerate(neg_to_plot):
#     label = c
#     color = colors[i % len(colors)]
#     plt.fill_between(time_h, mean_OD[c] - sems_OD[c], mean_OD[c] + sems_OD[c],
#                      color=color, alpha=0.5)
#     plt.plot(time_h, mean_OD[c], label=label, color=color,ls='--')
    
for i, c in enumerate(exp_to_plot):
    label = c
    color = colors[i % len(colors)]
    plt.fill_between(time_h, mean_OD[c] - sems_OD[c], mean_OD[c] + sems_OD[c],
                     color=color, alpha=0.5)
    plt.plot(time_h, mean_OD[c], label=label, color=color,ls='-.')
plt.legend(loc=2, fontsize=18)
plt.xlim(0, np.max(time_h)+.1)
plt.ylim(-0.1, 1.3)
plt.xticks(np.arange(0, np.max(time_h)+.1, 5), fontsize=14)
plt.yticks(fontsize=14)
plt.title('Growth proton wire', fontsize=20)
plt.xlabel('Time (Hours)', fontsize=20)
plt.ylabel('OD600', fontsize=20)

plt.show()

# %%
yields = means.GrowthYield(density_label='abs600')

labels = sorted(pos) + sorted(exp_to_plot) + sorted(neg)
ylds = [yields[l] for l in labels]

figure = plt.figure(figsize=(10,10))
xs = np.arange(len(ylds))
plt.bar(xs, ylds)
plt.title('', fontsize=20)
plt.ylabel('Growth Yield (OD600 Units)')
plt.xticks(xs + 0.4, labels, rotation=90)
plt.show()
