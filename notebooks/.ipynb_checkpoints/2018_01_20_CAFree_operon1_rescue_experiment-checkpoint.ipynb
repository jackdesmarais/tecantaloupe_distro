# %%
cd /mnt/59E0-214E/data/Jack/SavageLab/scripts/tecantaloupe
# Out:
# /mnt/59E0-214E/data/Jack/SavageLab/scripts/tecantaloupe

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn
import itertools

from growth.plate_spec import PlateSpec
from growth.plate_time_course_parser import SavageLabM1000Excel
from matplotlib import pyplot as plt

# %%
# PlateSpec defined in CSV for easy editing
ps = PlateSpec.FromFile('growth/plate_specs/2018_01_18_operon1CAFreeKnockInGrowth.csv')
name_mapping = ps.well_to_name_mapping()

# PlateSpec contains a DataFrame with the mapping. 
ps.df
# Out:
# value_type             name                                     \
# column                    1                 2                3
# A           bw+pFEsfGFP+atc  CAF+pFEsfgfp+atc  CAF+pJJD019+atc
# B           bw+pFEsfGFP+atc  CAF+pFEsfgfp+atc  CAF+pJJD019+atc
# C           bw+pFEsfGFP+atc  CAF+pFEsfgfp+atc  CAF+pJJD019+atc
# D           bw+pFEsfGFP+atc  CAF+pFEsfgfp+atc  CAF+pJJD019+atc
# E           bw+pFEsfGFP+atc  CAF+pFEsfgfp+atc  CAF+pJJD019+atc
# F           bw+pFEsfGFP+atc  CAF+pFEsfgfp+atc  CAF+pJJD019+atc
# G           bw+pFEsfGFP+atc  CAF+pFEsfgfp+atc  CAF+pJJD019+atc
# H           bw+pFEsfGFP+atc  CAF+pFEsfgfp+atc  CAF+pJJD019+atc
#
# value_type                                                                  \
# column                    4                5                6            7
# A           CAF+pJJD020+atc  CAF+pJJD021+atc  CAF+pJJD032+atc  bw+pFEsfGFP
# B           CAF+pJJD020+atc  CAF+pJJD021+atc  CAF+pJJD032+atc  bw+pFEsfGFP
# C           CAF+pJJD020+atc  CAF+pJJD021+atc  CAF+pJJD032+atc  bw+pFEsfGFP
# D           CAF+pJJD020+atc  CAF+pJJD021+atc  CAF+pJJD032+atc  bw+pFEsfGFP
# E           CAF+pJJD020+atc  CAF+pJJD021+atc  CAF+pJJD032+atc  bw+pFEsfGFP
# F           CAF+pJJD020+atc  CAF+pJJD021+atc  CAF+pJJD032+atc  bw+pFEsfGFP
# G           CAF+pJJD020+atc  CAF+pJJD021+atc  CAF+pJJD032+atc  bw+pFEsfGFP
# H           CAF+pJJD020+atc  CAF+pJJD021+atc  CAF+pJJD032+atc  bw+pFEsfGFP
#
# value_type
# column                 8            9           10           11           12
# A           CAF+pFEsfgfp  CAF+pJJD019  CAF+pJJD020  CAF+pJJD021  CAF+pJJD032
# B           CAF+pFEsfgfp  CAF+pJJD019  CAF+pJJD020  CAF+pJJD021  CAF+pJJD032
# C           CAF+pFEsfgfp  CAF+pJJD019  CAF+pJJD020  CAF+pJJD021  CAF+pJJD032
# D           CAF+pFEsfgfp  CAF+pJJD019  CAF+pJJD020  CAF+pJJD021  CAF+pJJD032
# E           CAF+pFEsfgfp  CAF+pJJD019  CAF+pJJD020  CAF+pJJD021  CAF+pJJD032
# F           CAF+pFEsfgfp  CAF+pJJD019  CAF+pJJD020  CAF+pJJD021  CAF+pJJD032
# G           CAF+pFEsfgfp  CAF+pJJD019  CAF+pJJD020  CAF+pJJD021  CAF+pJJD032
# H           CAF+pFEsfgfp  CAF+pJJD019  CAF+pJJD020  CAF+pJJD021  CAF+pJJD032

# %%
parser = SavageLabM1000Excel()
timecourse = parser.ParseFromFilename('growth/data/2018_01_20_CAFree_operon1_rescue_experiment.xlsx')

blanked = timecourse.blank()
# You can blank each well against it's own early timepoints
# by not setting blank_wells

# Smooth with default params.
smoothed = blanked.smooth()
# Out:
# growth/plate_time_course_parser.py:80: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   return clipped_df.convert_objects(convert_numeric=True)
# growth/plate_time_course.py:194: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=3,center=False).mean()
#   smoothed[key] = pd.rolling_mean(row, window)

# %%
# Smoothed & blanked data.
fig = plt.figure(figsize=(10,10))
OD_data = smoothed.data_for_label('abs600')
OD_data.plot(x='time_s', legend=False)
plt.show()

# %%
means = smoothed.mean_by_name(ps)
sems = smoothed.sem_by_name(ps)

mean_OD = means.data_for_label('abs600')
sems_OD = sems.data_for_label('abs600')

# %%
# groupings of samples for plotting
pos = [c for c in mean_OD.columns
       if c.startswith('bw') or c.startswith('CAF+pJJD032')]
neg = [c for c in mean_OD.columns
       if c.startswith('CAF+pFEsfgfp')]
exp = [c for c in mean_OD.columns
       if c.startswith('CAF+pJJD019') or c.startswith('CAF+pJJD020') or c.startswith('CAF+pJJD021')]

# %%
seaborn.set_style('white')
pos_to_plot = pos
exp_to_plot = exp
neg_to_plot = neg

plt.figure(figsize=(20,10))
time_h = mean_OD.time_s / (60.0*60.0)

colors = seaborn.color_palette()
for i, c in enumerate(sorted(pos_to_plot)):
    label = c
    color = colors[i % len(colors)]
    plt.fill_between(time_h, mean_OD[c] - sems_OD[c], mean_OD[c] + sems_OD[c],
                     color=color, alpha=0.5)
    plt.plot(time_h, mean_OD[c], label=label, color=color)

for i, c in enumerate(sorted(neg_to_plot)):
    label = c
    color = colors[i % len(colors)]
    plt.fill_between(time_h, mean_OD[c] - sems_OD[c], mean_OD[c] + sems_OD[c],
                     color=color, alpha=0.5)
    plt.plot(time_h, mean_OD[c], label=label, color=color, ls='--')
    
plt.legend(loc='best', fontsize=16)
plt.xlim(0, np.max(time_h)+.1)
plt.ylim(-0.1, 1.3)
plt.xticks(np.arange(0, np.max(time_h)+.1, 5), fontsize=14)
plt.yticks(fontsize=14)
plt.title('Growth  Controls', fontsize=20)
plt.xlabel('Time (Hours)', fontsize=20)
plt.ylabel('OD600', fontsize=20)

plt.show()

# %%
seaborn.set_style('white')
pos_to_plot = pos
exp_to_plot = exp
neg_to_plot = neg

plt.figure(figsize=(20,10))
time_h = mean_OD.time_s / (60.0*60.0)

colors = seaborn.color_palette()
for i, c in enumerate(sorted(exp_to_plot)):
    label = c
    color = colors[i % len(colors)]
    plt.fill_between(time_h, mean_OD[c] - sems_OD[c], mean_OD[c] + sems_OD[c],
                     color=color, alpha=0.5)
    plt.plot(time_h, mean_OD[c], label=label, color=color, lw=3, ls='-.')

for i, c in enumerate(sorted(neg_to_plot)):
    label = c
    color = colors[i % len(colors)]
    plt.fill_between(time_h, mean_OD[c] - sems_OD[c], mean_OD[c] + sems_OD[c],
                     color=color, alpha=0.5)
    plt.plot(time_h, mean_OD[c], label=label, color=color, ls='--')
    
plt.legend(loc='best', fontsize=16)
plt.xlim(0, np.max(time_h)+.1)
plt.ylim(-0.1, 1.3)
plt.xticks(np.arange(0, np.max(time_h)+.1, 5), fontsize=14)
plt.yticks(fontsize=14)
plt.title('Growth  Experiments', fontsize=20)
plt.xlabel('Time (Hours)', fontsize=20)
plt.ylabel('OD600', fontsize=20)

plt.show()

# %%
seaborn.set_style('white')
pos_to_plot = pos
exp_to_plot = exp
neg_to_plot = neg

plt.figure(figsize=(20,10))
time_h = mean_OD.time_s / (60.0*60.0)

colors = seaborn.color_palette()
for i, c in enumerate(sorted(exp_to_plot)):
    label = c
    color = colors[i % len(colors)]
    plt.fill_between(time_h, mean_OD[c] - sems_OD[c], mean_OD[c] + sems_OD[c],
                     color=color, alpha=0.5)
    plt.plot(time_h, mean_OD[c], label=label, color=color, lw=3, ls='-.')

for i, c in enumerate(sorted(pos_to_plot)):
    label = c
    color = colors[i % len(colors)]
    plt.fill_between(time_h, mean_OD[c] - sems_OD[c], mean_OD[c] + sems_OD[c],
                     color=color, alpha=0.5)
    plt.plot(time_h, mean_OD[c], label=label, color=color, ls='--')
    
plt.legend(loc='best', fontsize=16)
plt.xlim(0, np.max(time_h)+.1)
plt.ylim(-0.1, 1.3)
plt.xticks(np.arange(0, np.max(time_h)+.1, 5), fontsize=14)
plt.yticks(fontsize=14)
plt.title('Growth  Experiments', fontsize=20)
plt.xlabel('Time (Hours)', fontsize=20)
plt.ylabel('OD600', fontsize=20)

plt.show()

# %%
lag_times = means.LagTime(density_label='abs600')

labels = sorted(pos) + sorted(exp) + sorted(neg)
lags = [lag_times[l] for l in labels]

# Note - samples that don't cross the threshold get a 0 lag value.
figure = plt.figure(figsize=(10,10))
xs = np.arange(len(lags))
plt.bar(xs, lags)
plt.ylabel('Lag Time (hrs)')
plt.xticks(xs + 0.4, labels, rotation=90)
plt.show()

# %%
growth_rates = means.MaxGrowthRates(density_label='abs600')

labels = sorted(pos) + sorted(exp) + sorted(neg)
grs = [growth_rates[l] for l in labels]

figure = plt.figure(figsize=(10,10))
xs = np.arange(len(lags))
plt.bar(xs, grs)
plt.ylabel('Max Growth Rate (/hr)')
plt.xticks(xs + 0.4, labels, rotation=90)
plt.show()
# Out:
# growth/plate_time_course.py:384: RuntimeWarning: invalid value encountered in log
#   log_data = np.log(well_data)
# growth/plate_time_course.py:394: RuntimeWarning: All-NaN axis encountered
#   if np.nanmin(local_data) < log_lb:

# %%
yields = means.GrowthYield(density_label='abs600')

labels = sorted(pos) + sorted(exp) + sorted(neg)
ylds = [yields[l] for l in labels]

figure = plt.figure(figsize=(10,10))
xs = np.arange(len(ylds))
plt.bar(xs, ylds)
plt.ylabel('Growth Yield (OD600 Units)')
plt.xticks(xs + 0.4, labels, rotation=90)
plt.show()
